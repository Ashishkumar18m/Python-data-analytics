# %%
import module

# %%
import importlib
import module
importlib.reload(module)
# Out:
# <module 'module' from 'C:\\Users\\ashish\\Sem - 2\\module.py'>

# %%
x=float(input("enter 1st number:"))
y=float(input("Enter 2nd number:"))
n=int(input("Enter 1 for add  , Enter 2 for subtract  , Enter 3 for multiply  , Enter 4 for divide:"))
if n==1:
    print("The sum is =")
elif n==2:
    print("The subtraction is =")
elif n==3:
    print("The multiply is =")
elif n==4:
    print("The division is =")
else:
    print("Invalid number")
print(module.arthmatic(x,y,n))

# %%
num=int(input("Enter number to calculate factorial : "))
print("The factorial of the number is =",module.factorial(num))
# Out:
# Enter number to calculate factorial :  3
# The factorial of the number is = 6

# %%
with open("textfile.txt", "w") as file:
    file.write("Hello Ashish Kumar\n")
    file.write("A B.tech student\n")

# %%
with open("textfile.txt", "r") as file:
    content=file.read()
    print(content)
# Out:
# Hello Ashish Kumar
# A B.tech student

# %%
with open("textfile.txt", "a") as file:
    file.write("1st sen cgpa of 8.58.")

# %%
with open("textfile.txt", "r") as file:
    content=file.read()
    print(content)
# Out:
# Hello Ashish Kumar
# A B.tech student
# 1st sen cgpa of 8.58.

# %%
with open("textfile.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello Ashish Kumar
# A B.tech student
# 1st sen cgpa of 8.58.

# %%
with open("textfile.txt", "r") as file:
    content=file.read(7)
    print(content)
# Out:
# Hello A

# %%
with open("textfile.txt", "r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['Hello Ashish Kumar\n', 'A B.tech student\n', '1st sen cgpa of 8.58.']

# %%
with open("textfile.txt", "r") as file:
    content=file.read()
    print(content)
# Out:
# Hello Ashish Kumar
# A B.tech student
# 1st sen cgpa of 8.58.

# %%
import csv
import os
with open('tips.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import csv
#       2 import os
# ----> 3 with open('tips.csv', 'r') as file:
#       4     csv_reader = csv.reader(file)
#       5     for row in csv_reader:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tips.csv'

# %%
import tips.csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tips.csv
#
# ModuleNotFoundError: No module named 'tips'
