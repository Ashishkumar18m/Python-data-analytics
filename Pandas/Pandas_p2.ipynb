# %%
import pandas as pd

# %% [markdown]
# # read csv

# %%
df=pd.read_csv("C:\\Users\\ashish\\Downloads\\Indian_Kids_Screen_Time.csv")
display(df)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %% [markdown]
# # display complete csv

# %%
# in text
display(df.to_string())

# in csv
# Out:
# '      Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio                                 Health_Impacts Urban_or_Rural\n0      14    Male                      3.99     Smartphone                        True                               0.42                         Poor Sleep, Eye Strain          Urban\n1      11  Female                      4.61         Laptop                        True                               0.30                                     Poor Sleep          Urban\n2      18  Female                      3.73             TV                        True                               0.32                                     Poor Sleep          Urban\n3      15  Female                      1.21         Laptop                       False                               0.39                                            NaN          Urban\n4      12  Female                      5.89     Smartphone              
# ...

# %% [markdown]
# # find index of an element

# %%
d=df[df["Avg_Daily_Screen_Time_hr"]==3.26].index
display(d)
# Out:
# Index([ 137,  556,  708,  980, 1318, 1376, 2416, 2522, 2601, 4063, 4462, 5673,
#        5979, 6234, 7516, 9591, 9707],
#       dtype='int64')

# %% [markdown]
# # display complete row when index match / or it is a new data frame

# %%
dj=df[df["Avg_Daily_Screen_Time_hr"]==3.26]
display(dj)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 137    14    Male                      3.26     Smartphone
# 556    18    Male                      3.26         Laptop
# 708    13    Male                      3.26     Smartphone
# 980    15  Female                      3.26             TV
# 1318   13    Male                      3.26             TV
# 1376   13    Male                      3.26     Smartphone
# 2416   12    Male                      3.26         Laptop
# 2522   14    Male                      3.26     Smartphone
# 2601   11  Female                      3.26         Laptop
# 4063   11    Male                      3.26             TV
# 4462   18  Female                      3.26         Laptop
# 5673   18  Female                      3.26         Tablet
# 5979   10    Male                      3.26     Smartphone
# 6234    9  Female                      3.26             TV
# 7516   18  Female                      3.26             TV
# ...

# %% [markdown]
# # make new data frame from older

# %%
du=df[["Avg_Daily_Screen_Time_hr","Primary_Device"]]
display(du)
# Out:
#       Avg_Daily_Screen_Time_hr Primary_Device
# 0                         3.99     Smartphone
# 1                         4.61         Laptop
# 2                         3.73             TV
# 3                         1.21         Laptop
# 4                         5.89     Smartphone
# ...                        ...            ...
# 9707                      3.26     Smartphone
# 9708                      4.43     Smartphone
# 9709                      5.62     Smartphone
# 9710                      5.60             TV
# 9711                      6.12             TV
#
# [9712 rows x 2 columns]

# %% [markdown]
# # make new data frame from older when condition match on element

# %%
#dk=df["Avg_Daily_Screen_Time_hr"]
#dk=pd.DataFrame(dk)
#display(dk)


dk=df[df["Avg_Daily_Screen_Time_hr"]==3.26]
display(dk)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 137    14    Male                      3.26     Smartphone
# 556    18    Male                      3.26         Laptop
# 708    13    Male                      3.26     Smartphone
# 980    15  Female                      3.26             TV
# 1318   13    Male                      3.26             TV
# 1376   13    Male                      3.26     Smartphone
# 2416   12    Male                      3.26         Laptop
# 2522   14    Male                      3.26     Smartphone
# 2601   11  Female                      3.26         Laptop
# 4063   11    Male                      3.26             TV
# 4462   18  Female                      3.26         Laptop
# 5673   18  Female                      3.26         Tablet
# 5979   10    Male                      3.26     Smartphone
# 6234    9  Female                      3.26             TV
# 7516   18  Female                      3.26             TV
# ...

# %% [markdown]
# # make new data frame with first n rows.

# %%
dl=(df.head(10))
display(dl)
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
# 5   14  Female                      4.88     Smartphone
# 6   17    Male                      2.97             TV
# 7   10    Male                      2.74             TV
# 8   14    Male                      4.61         Laptop
# 9   18    Male                      3.24         Tablet
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# ...

# %% [markdown]
# # sort the data on two or one condition (numerical/letters)

# %%
dn=df.sort_values(["Avg_Daily_Screen_Time_hr","Educational_to_Recreational_Ratio"], ascending=(True,False))
display(dn)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 672     9  Female                      0.00     Smartphone
# 1700    9  Female                      0.00     Smartphone
# 2310   10  Female                      0.00     Smartphone
# 6087   10  Female                      0.00             TV
# 6903   10    Male                      0.00     Smartphone
# ...   ...     ...                       ...            ...
# 1321   10  Female                     12.09         Tablet
# 1870   10    Male                     12.40     Smartphone
# 1769    9    Male                     12.80             TV
# 934    10  Female                     13.01     Smartphone
# 4298   10  Female                     13.89     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 672                        False                               0.60
# 1700                       False                               0.60
# ...

# %%
dn=df.sort_values(["Primary_Device","Exceeded_Recommended_Limit"], ascending=(True,False))
display(dn)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 1      11  Female                      4.61         Laptop
# 8      14    Male                      4.61         Laptop
# 35     16  Female                      3.50         Laptop
# 49     17    Male                      4.29         Laptop
# 62     13    Male                      4.50         Laptop
# ...   ...     ...                       ...            ...
# 9408    9    Male                      0.15         Tablet
# 9482    8    Male                      0.00         Tablet
# 9522   11    Male                      1.99         Tablet
# 9667    8  Female                      0.89         Tablet
# 9689    8    Male                      1.90         Tablet
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 1                           True                               0.30
# 8                           True                               0.36
# ...

# %%
dn=df.sort_values(("Exceeded_Recommended_Limit"),ascending=False)
display(dn)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 6202    9  Female                      6.81             TV
# 6196   17    Male                      4.31     Smartphone
# 6197   10  Female                      5.11     Smartphone
# 6198    8  Female                      2.93     Smartphone
# ...   ...     ...                       ...            ...
# 854    16    Male                      1.69         Tablet
# 7188    9  Female                      0.00             TV
# 6305   10  Female                      1.99             TV
# 8703    8  Female                      0.00             TV
# 6670    9    Male                      0.90     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 6202                        True                               0.55
# ...

# %% [markdown]
# # Add a row in data frame

# %%
dy={
    "Age":15,
    "Gender":'Male',
    "Avg_Daily_Screen_Time_hr":3.99,
    "Primary_Device":'Smartphone',
    "Exceeded_Recommended_Limit":True,
    "Educational_to_Recreational_Ratio":0.42,
    "Health_Impacts":'Poor Sleep',
    "Urban_or_Rural":'Urban'
}
df=pd.concat([df,pd.DataFrame([dy])],ignore_index=True)
display(df)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
# 9712   15    Male                      3.99     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %% [markdown]
# # add a row in data frame at particular index

# %%
dy={
    "Age":15,
    "Gender":'Male',
    "Avg_Daily_Screen_Time_hr":3.99,
    "Primary_Device":'Smartphone',
    "Exceeded_Recommended_Limit":True,
    "Educational_to_Recreational_Ratio":0.42,
    "Health_Impacts":'Poor Sleep',
    "Urban_or_Rural":'Urban'
}
df.loc[2]=[dy]

display(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 11
#       1 dy={
#       2     "Age":15,
#       3     "Gender":'Male',
#    (...)
#       9     "Urban_or_Rural":'Urban'
#      10 }
# ---> 11 df.loc[2]=[dy]
#      13 display(df)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
# ...

# %% [markdown]
# # Add a column in data frame

# %%
df["New"]=df["Age"]+2
display(df)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
# 9712   15    Male                      3.99     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df["new2"]=("s")
display(df)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
# 9712   15    Male                      3.99     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df["Is_adult"]=df["Age"]>=18
display(df)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
# 9712   15    Male                      3.99     Smartphone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %% [markdown]
# # Modify the data

# %%
df.loc[df["Primary_Device"]=='Smartphone',"Primary_Device"]='SmartPhone'
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     SmartPhone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      15  Female                      1.21         Laptop
# 4      12  Female                      5.89     SmartPhone
# ...   ...     ...                       ...            ...
# 9708   17  Female                      4.43     SmartPhone
# 9709   16    Male                      5.62     SmartPhone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
# 9712   15    Male                      3.99     SmartPhone
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df.loc[df["Age"]==15,"Age"]=15+2
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                      3.99     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73             TV
# 3      17  Female                      1.21         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   17  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df["Age"]=df["Age"]+2
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      16    Male                      3.99     Smartphone
# 1      13  Female                      4.61         Laptop
# 2      20  Female                      3.73             TV
# 3      19  Female                      1.21         Laptop
# 4      14  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   19    Male                      3.26     Smartphone
# 9708   19  Female                      4.43     Smartphone
# 9709   18    Male                      5.62     Smartphone
# 9710   19    Male                      5.60             TV
# 9711   19  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...
