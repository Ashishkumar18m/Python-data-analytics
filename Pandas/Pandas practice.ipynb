# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# # Read csv file

# %%
df=pd.read_csv("C:\\Users\\ashish\\Downloads\\Netflix_sample_500 (1).csv")
display(df.head())
display(df.tail(5))
# Out:
#   show_id     type    title    director              cast         country  \
# 0      s1    Movie  Title 1  Director A           Actor E  United Kingdom
# 1      s2    Movie  Title 2  Director C  Actor A, Actor B           India
# 2      s3  TV Show  Title 3  Director D               NaN           India
# 3      s4    Movie  Title 4  Director C  Actor A, Actor B  United Kingdom
# 4      s5    Movie  Title 5  Director B               NaN          France
#
#    date_added  release_year rating   duration                 listed_in
# 0  2020-03-09          2008      R  5 Seasons        Action & Adventure
# 1  2019-10-10          2020  PG-13     84 min  Children & Family Movies
# 2  2020-09-03          2004  PG-13  2 Seasons                  Comedies
# 3  2019-10-06          2004     PG  4 Seasons             Documentaries
# 4  2020-03-05          2007  PG-13  1 Seasons                  Comedies
#     show_id     type      title    director                       cast  \
# ...

# %% [markdown]
# # sort the data

# %%
df=(df.sort_values("release_year"))
df
# Out:
#     show_id     type      title    director                       cast  \
# 249    s250  TV Show  Title 250  Director B           Actor A, Actor B
# 465    s466  TV Show  Title 466  Director D                    Actor E
# 292    s293  TV Show  Title 293  Director D           Actor A, Actor B
# 159    s160    Movie  Title 160  Director C                    Actor E
# 30      s31  TV Show   Title 31  Director A                        NaN
# ..      ...      ...        ...         ...                        ...
# 435    s436  TV Show  Title 436  Director C                        NaN
# 120    s121    Movie  Title 121  Director D           Actor C, Actor D
# 356    s357    Movie  Title 357  Director D                    Actor E
# 422    s423    Movie  Title 423         NaN  Actor F, Actor G, Actor H
# 98      s99    Movie   Title 99  Director C                    Actor E
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# # Make new data frame from above

# %%
dj= df[['rating', 'type',"title","country"]]
dj=pd.DataFrame(dj)
print(dj.to_string())
# Out:
#     rating     type      title         country
# 0        R    Movie    Title 1  United Kingdom
# 1    PG-13    Movie    Title 2           India
# 3       PG    Movie    Title 4  United Kingdom
# 4    PG-13    Movie    Title 5          France
# 5    TV-MA    Movie    Title 6          Canada
# 6    TV-MA    Movie    Title 7           India
# 7        R    Movie    Title 8           India
# 8    PG-13  TV Show    Title 9           India
# 9    TV-14    Movie   Title 10           India
# 10   PG-13    Movie   Title 11   United States
# 11   TV-14    Movie   Title 12  United Kingdom
# 12       G    Movie   Title 13          France
# 13   NC-17    Movie   Title 14          France
# 14      PG    Movie   Title 15   United States
# 15   TV-14    Movie   Title 16           Spain
# 16       G  TV Show   Title 17          France
# 17   NC-17    Movie   Title 18           Spain
# 18      PG  TV Show   Title 19          France
# 19   NC-17  TV Show   Title 20          Mexico
# ...

# %% [markdown]
# ## Add a row

# %%
new={
    "show_id": "s501",
    "type": "TV Show",
    "title": "Title 501",
    "director": "Director D",
    "cast": "Actor E, Actor A",
    "country": "India",
    "date_added": "2020-12-01",
    "release_year": 2021,
    "rating": "TV-MA",
    "duration": "3 Seasons",
    "listed_in": "Comedies"
    
}
df=pd.concat([df,pd.DataFrame([new])])
display(df.tail(5))
# Out:
#     show_id     type      title    director              cast         country  \
# 496    s497  TV Show  Title 497  Director C               NaN  United Kingdom
# 497    s498    Movie  Title 498  Director C           Actor E           India
# 498    s499  TV Show  Title 499  Director A  Actor A, Actor B          Mexico
# 499    s500    Movie  Title 500  Director D           Actor E           Spain
# 0      s501  TV Show  Title 501  Director D  Actor E, Actor A           India
#
#      date_added  release_year rating   duration      listed_in
# 496  2017-10-10          2019  NC-17  5 Seasons  Documentaries
# 497  2020-09-28          2019  NC-17  4 Seasons       Comedies
# 498  2016-02-27          2007      R    144 min       Comedies
# 499  2015-07-25          2020      R     89 min  Horror Movies
# 0    2020-12-01          2021  TV-MA  3 Seasons       Comedies

# %% [markdown]
# ## Delete a row

# %%
df = df.drop(2)              #(say row with index 2)
display(df.head())

df = df[df["title"] != "Title1"]
display(df)

#df = df[df['type'] != 'Movie']     #remove all rows where type == 'Movie')
# Out:
#   show_id   type    title    director                       cast  \
# 0      s1  Movie  Title 1  Director A                    Actor E
# 1      s2  Movie  Title 2  Director C           Actor A, Actor B
# 3      s4  Movie  Title 4  Director C           Actor A, Actor B
# 4      s5  Movie  Title 5  Director B                        NaN
# 5      s6  Movie  Title 6  Director D  Actor F, Actor G, Actor H
#
#           country  date_added  release_year rating   duration  \
# 0  United Kingdom  2020-03-09          2008      R  5 Seasons
# 1           India  2019-10-10          2020  PG-13     84 min
# 3  United Kingdom  2019-10-06          2004     PG  4 Seasons
# 4          France  2020-03-05          2007  PG-13  1 Seasons
# 5          Canada  2019-12-20          2004  TV-MA     68 min
#
#                   listed_in
# 0        Action & Adventure
# 1  Children & Family Movies
# 3             Documentaries
# 4                  Comedies
# 5                    Dramas
# ...

# %% [markdown]
# ## Modify Text inside CSV

# %%
i=df.index[df["type"]=="Title 3"].tolist()
print(i)
df.loc[3, "title"] = "New Title 4"        # changes Title in row index 2 (by index and column)
display(df.head(5))

#df.loc[df["type"] == "Movie", "type"] = "Film"   #Change all rows where type == 'Movie' to 'Film'
# Out:
# []

# %%
invt1={
    'pen':[2],
    'orange':[1],
    'pencil':[2],
    'notebook':[4]
}
invt2={
    'pen':[4],
    'orange':[2],
    'pencil':[3],
    'notebook':[5]
}

df3=pd.DataFrame(invt1)
df4=pd.DataFrame(invt2)
print("invt 1\n:",df3)
print("invt 2\n:",df4)
# Out:
# invt 1
# :    pen  orange  pencil  notebook
# 0    2       1       2         4
# invt 2
# :    pen  orange  pencil  notebook
# 0    4       2       3         5

# %%
# Element-wise comparison.
#df3 > df4
df3 >=df4
#df3 < df4
#df3 <= df4
# Out:
#      pen  orange  pencil  notebook
# 0  False   False   False     False

# %%
df3.compare(df4)
# Out:
#    pen       orange       pencil       notebook
#   self other   self other   self other     self other
# 0    2     4      1     2      2     3        4     5

# %%
pd.concat([df3, df4])
# Out:
#    pen  orange  pencil  notebook
# 0    2       1       2         4
# 0    4       2       3         5

# %%
data={
    'Name':["Harsh","Dev","Kapil","Kunal","Ayush","Mohit"],
    'Marks':[31,23,75,67,70,81],
    'Age':[17,18,18,20,19,21]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks  Age
# 0  Harsh     31   17
# 1    Dev     23   18
# 2  Kapil     75   18
# 3  Kunal     67   20
# 4  Ayush     70   19
# 5  Mohit     81   21

# %%
df=pd.Series(data)
print(df)
# Out:
# Name     [Harsh, Dev, Kapil, Kunal, Ayush, Mohit]
# Marks                    [31, 23, 75, 67, 70, 81]
# Age                      [17, 18, 18, 20, 19, 21]
# dtype: object
